# %% [markdown]
# # Grafico 06 - Arquetipos de areas protegidas segun patron de superficie natural
#
# Este notebook reproduce en Google Colab la imagen de arquetipos, la tabla de soporte en Excel, y el detalle por AP en un CSV.
#
# **Antes de correr las celdas de abajo**, ten a mano el archivo `naturalidad_data.json` (esta en la carpeta `codigo/` de este grafico, en tu computador o en tu repositorio de GitHub).
#
# Corre las celdas en orden, de arriba hacia abajo.

# %% [markdown]
# ## 1. Instalar paquetes

# %%
# !pip -q install numpy pandas matplotlib openpyxl scikit-learn

# %% [markdown]
# ## 2. Subir el archivo de datos

# %%
from google.colab import files
print("Sube aqui: naturalidad_data.json")
uploaded = files.upload()

# %% [markdown]
# ## 3. Generar la imagen de arquetipos

# %%
# Arquetipos clustering code

# %% [markdown]
# ## 4. Generar la tabla de soporte (Excel)

# %%
# Table generation code

# %% [markdown]
# ## 5. Ver la imagen generada

# %%
import glob
from IPython.display import Image, display

for p in sorted(glob.glob(os.path.join(OUT_DIR, '*.png'))):
    print(p.split('/')[-1])
    display(Image(filename=p))

# %% [markdown]
# ## 6. Descargar todo (imagen + tabla de soporte + CSV por AP) en un .zip

# %%
import shutil, os
from google.colab import files

RESULT_DIR = "/content/resultados_06_arquetipos"
os.makedirs(RESULT_DIR, exist_ok=True)
if os.path.isdir(OUT_DIR):
    shutil.copytree(OUT_DIR, os.path.join(RESULT_DIR, "imagenes"), dirs_exist_ok=True)
if os.path.exists(OUT_XLSX):
    shutil.copy(OUT_XLSX, RESULT_DIR)
if os.path.exists(os.path.join(OUT_DIR_ARRIBA, "arquetipos_por_AP.csv")):
    shutil.copy(os.path.join(OUT_DIR_ARRIBA, "arquetipos_por_AP.csv"), RESULT_DIR)
shutil.make_archive(RESULT_DIR, "zip", RESULT_DIR)
files.download(RESULT_DIR + ".zip")
print("Listo:", RESULT_DIR + ".zip")
